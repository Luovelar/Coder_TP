# %% [markdown]
# # Análisis de Datos - Acidentes_Brasil_2020-2023
#
# ## Introducción
#
# En este análisis, se explorará un conjunto de datos que contiene información sobre los accidentes víales ocurridos en Brazil desde el año 2020 hasta mediado del años 2022. El objetivo es responder a varias preguntas de interés y probar algunas hipótesis relacionadas con los accidentes víales en el país mencionado.
#
# Analizar datos relacionados con accidentes de tráfico proporciona una visión profunda de los patrones y factores que contribuyen a estos incidentes, permitiendo una toma de decisiones más informada y eficaz. En este contexto, hemos obtenido un conjunto de datos exhaustivo que abarca varios años de accidentes de tráfico en Brasil, que incluye detalles como la fecha y la hora del accidente, las condiciones meteorológicas, el tipo de carretera, así como información sobre víctimas y daños materiales.
#
# Explorar estos datos no solo nos permite comprender las circunstancias que rodean los accidentes, sino también identificar tendencias y patrones que podrían contribuir significativamente a la mejora de la seguridad vial en el país. Por ente, este análisis no solo representa una exploración numérica, sino una búsqueda profunda en los matices de la seguridad vial. Los datos proporcionan una ventana a las condiciones meteorológicas impredecibles, las complejidades de los patrones de tráfico, y la interacción humana en el contexto de la conducción. Entender cómo estos factores que se interconectan es fundamental para mejorar la seguridad en las rutas.
#
# También es una búsqueda para comprender las complejidades detrás de cada accidente, para discernir patrones que ayudarán a las autoridades a tomar decisiones más informadas y a la sociedad a conducir de manera más segura. En este estudio, nos sumergimos en los datos, buscando respuestas que no solo informen políticas públicas, sino que también salven vidas. A medida que desglosamos estos datos, nos encontramos no solo con estadísticas, sino con historias; historias que nos instan a mejorar, a aprender y a trabajar hacia un futuro donde las carreteras brasileñas sean más seguras para todos.

# %% [markdown]
# ### El contexto y el problema comercial
#
#  El contexto comercial se basa en la necesidad de tomar medidas preventivas informadas para reducir la cantidad de accidentes en las carreteras brasileñas. Nos centramos en comprender y mejorar la seguridad vial en Brasil a través del análisis de datos detallados sobre accidentes de tráfico.
#
#  El problema comercial radica en la creciente preocupación por la seguridad vial y la necesidad de aplicar soluciones prácticas. En el contexto analítico, se consideran diversas técnicas y modelos predictivos para obtener insights significativos de los datos. La exploración de datos revela patrones, tendencias y correlaciones, proporcionando una base sólida para futuros análisis y decisiones orientadas a la seguridad vial.

# %% [markdown]
# ## Recomendaciones basadas en Insights Observados
#
# - Los accidentes son más frecuentes durante las horas pico de tráfico, especialmente durante los nes de semanas.
# - La gravedad de los accidentes tiende a aumentar durante condiciones meteorológicas con cielo claro.
# - Las autopistas tienen una mayor propensión a accidentes graves en comparación con las calles urbanas.
# - Existen áreas geográficas específicas con una alta concentración de ciertos tipos de accidentes, lo que sugiere la necesidad de medidas de seguridad específicas en esas zonas.

# %% [markdown]
# ### Hipótesis
#
# 1.  La gravedad de los accidentes de tráfico es mayor en las autopistas que en las calles urbanas debido a la alta velocidad permitida en las autopistas.
# 2. Los accidentes de tráfico son más frecuentes durante los días laborables (de lunes a viernes) en comparación con los fines de semana, debido al aumento del tráfico durante las horas pico.
# 3. La gravedad de los accidentes es más alta durante las condiciones meteorológicas adversas, como lluvia intensa o neblina, debido a la reducción de la visibilidad y la disminución del agarre en la carretera
# 4. Las zonas urbanas densamente pobladas tienen una mayor incidencia de accidentes de tráfico debido a la congestión del tráfico y a la interacción cercana entre vehículos y peatones.

# %% [markdown]
# ### Preguntas de Interés
#
# 1. ¿Cuál es la tendencia en el número total de accidentes a lo largo de los años?
# 2. ¿Existe una estacionalidad en la ocurrencia de accidentes a lo largo de los meses o las estaciones del año?
# 3. ¿Cuáles son las condiciones meteorológicas más comunes en los accidentes y cómo afectan a la gravedad de los mismos "Mortos, Feridos_leves, Feridos_graves, Ilesos o Ignorados"?
# 4. ¿Qué días de la semana tienen la mayor cantidad de accidentes y cómo varía esta distribución?
# 5. ¿Cómo se distribuyen los tipos de carreteras en relación con los accidentes?
# 6. ¿Cuál es el mes y el día con mayor cantidad de accidentes a lo largo de los años analizados?
# 7. ¿Cómo varía el número de accidentes a lo largo de un solo día?
# 8. ¿Cuáles son las Unidades Federales con mayores índices de accidentes?

# %% [markdown]
# ### Objetivo del Proyecto:
#
# El propósito principal de este proyecto es analizar y visualizar los datos de accidentes de tráfico recopilados durante este período. Mi objetivo es identificar patrones y tendencias que puedan proporcionar una comprensión más profunda de las circunstancias que rodean los accidentes. Además, busco desarrollar visualizaciones interactivas que sean accesibles para el público en general y que puedan crear conciencia sobre la importancia de la seguridad vial.

# %% [markdown]
# ### Enfoque Metodológico:
#
# Este proyecto se enfocará en el análisis detallado de los datos de accidentes de tráfico en Brasil desde el año 2020 hasta mediados de 2023. Utilizaré técnicas estadísticas de regresión lineal para comprender, visualizar patrones y ver las tendencias dentro de los conjuntos de datos para descubrir correlaciones significativas entre diversas variables, como ubicación, hora del día, condiciones meteorológicas y tipos de carreteras, y la frecuencia de los accidentes.
#
# Al comprender mejor los patrones de los accidentes de tráfico, espero poder crear conciencia y fomentar una conducción más segura en la sociedad en general. Además, esta experiencia me brinda la oportunidad de aprender sobre problemas del mundo real y aplicar soluciones prácticas.

# %% [markdown]
# ### Planteamiento de la Exploración de Datos: Accidentes de Tráfico en Brasil (2020-2023)
#
# 1. Descripción General: Los datos incluyen información sobre accidentes de tráfico en Brasil desde 2020 hasta mediados de 2023. Variables disponibles: fecha y hora del accidente, ubicación geográfica (latitud y longitud), condiciones meteorológicas, tipo de carretera, número de víctimas, gravedad del accidente, etc.
#
# 2. Análisis Univariable:
#
# Variables Numéricas: Se calcularan estadísticas descriptivas como media, mediana y desviación estándar para el número de víctimas por accidente.
# Variables Categóricas: Se examinará la distribución de los tipos de carreteras involucradas en los accidentes para entender las proporciones de autopistas, calles urbanas, etc.
#
# 3. Análisis Bivariable:
# Correlaciones: Se analizará la relación entre la gravedad del accidente y la hora del día para determinar si hay un aumento en la gravedad durante ciertas horas. Se examinan las correlaciones entre las condiciones meteorológicas y el número de accidentes para identificar patrones climáticos asociados con más accidentes.
# Exploración Temporal: Se crea un gráfico de línea para visualizar la tendencia anual de accidentes a lo largo del período.
# 4. Visualización de Datos:
#
# Gráficos de Barras y Torta: Se generará un gráfico de barras para mostrar la frecuencia de diferentes tipos de accidentes.
#
# Mapas: Se utilizará un mapa para mostrar la distribución geográfica de los accidentes, con puntos de colores que indican la gravedad del accidente.

# %% [markdown]
# ### Contexto analítico
# Para poder desarrollar el modelo se cuenta con un conjunto de
#
# Las variables disponibles (30) son las siguientes:
# 1	Id_acidente
# 2	Año_acidente
# 3	Dia_semana: Los días de semanas de los accidentes
# 4	Horario: Horario de ocurrencia de cada accidente
# 5	Unidad_federal: División por estados y regiones
# 6	Br: El el número de las rutas o autopistas
# 7	Km: El kilómetro en dónde ocurren los accidentes
# 8	Municipio: Municio de ocurrencia de los accidentes
# 9	Causa_acidente
# 10	Tipo_acidente: Motivo de los accidentes
# 11	Classificacao_acidente: Clasificación de los accidentes de acuerdo al estado de las victimas
# 12	Fase_dia: Horario del día del accidente
# 13	Sentido_via: Dirección del carril
# 14	Condicao_metereologica: La condición climática de los accidentes
# 15	Tipo_pista: Tipos de pistas de las rutas
# 16	Tracado_via: Disposición de las vías
# 17	Uso_solo: Muestra si los carriles son manos únicas o dobles
# 18	Pessoas: Cantidad de persnas afectadas
# 19	Mortos: Cantidad personas fallecidas
# 20	Feridos_leves: Números de personas con herídas leves
# 21	Feridos_graves: Números de personas con herídas graves
# 22	Ilesos: Números de personas hilésos
# 23	Ignorados: Números de personas sin registro de estado
# 24	Feridos: Números de personas con herídas
# 25	Veiculos: Cantidad de veículos involucrados
# 26	Latitude
# 27	Longitude
# 28	Regional: Región en la cual se predujo el accidente
# 29	Delegacia: Delegación de las denuncias
# 30	uop: Id de la delegación

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as mpl
import matplotlib.pyplot as plt
import warnings
from matplotlib.ticker import FuncFormatter
import folium
from folium import plugins
import contextily as ctx
from urllib.request import urlopen

from io import StringIO
import statsmodels.api as sm

# %%
warnings.filterwarnings("ignore")

url = 'https://raw.githubusercontent.com/Luovelar/Coder_TP/main/Acidentes_Brasil_2020-2022.csv'

with urlopen(url) as response:
    data = response.read().decode('ISO-8859-1').splitlines()

data = '\n'.join(data)
df = pd.read_csv(StringIO(data), delimiter=';')

(df.head(5))
# Out:
#    Id_acidente Año_acidente    Dia_semana   Horario Unidad_federal     Br  \
# 0     260068.0     1/1/2020  quarta-feira  05:40:00             PA  316.0
# 1     260073.0     1/1/2020  quarta-feira  06:00:00             MG  262.0
# 2     260087.0     1/1/2020  quarta-feira  06:00:00             BA  116.0
# 3     260116.0     1/1/2020  quarta-feira  10:08:00             SP  116.0
# 4     260129.0     1/1/2020  quarta-feira  12:10:00             MG  262.0
#
#       Km              Municipio                      Causa_acidente  \
# 0     84  SAO FRANCISCO DO PARA         Falta de Atenção à Condução
# 1    804                UBERABA         Falta de Atenção à Condução
# 2    191                CANUDOS                   Condutor Dormindo
# 3     71              APARECIDA  Não guardar distância de segurança
# 4  380,9                JUATUBA                   Condutor Dormindo
#
#                Tipo_acidente  ... Feridos_graves Ilesos Ignorados Feridos  \
# ...

# %%
df['Año_acidente'] = pd.to_datetime(df['Año_acidente'], format='%d/%m/%Y', errors='coerce')

df = df.dropna(subset=['Año_acidente'])

df['Año'] = df['Año_acidente'].dt.year

# Manejo de valores faltantes
df.dropna(inplace=True)

# Conversión de tipos de datos
df['Año_acidente'] = pd.to_datetime(df['Año_acidente'])

# %% [markdown]
# # Exploración valores vacíos

# %%
valores_nulos  = df.isnull().sum()
columnas_con_nulos = valores_nulos[valores_nulos == 0]
columnas_con_nulos
# Out:
# Id_acidente               0
# Año_acidente              0
# Dia_semana                0
# Horario                   0
# Unidad_federal            0
# Br                        0
# Km                        0
# Municipio                 0
# Causa_acidente            0
# Tipo_acidente             0
# Classificacao_acidente    0
# Fase_dia                  0
# Sentido_via               0
# Condicao_metereologica    0
# Tipo_pista                0
# Tracado_via               0
# Uso_solo                  0
# Pessoas                   0
# Mortos                    0
# Feridos_leves             0
# Feridos_graves            0
# Ilesos                    0
# Ignorados                 0
# Feridos                   0
# Veiculos                  0
# Latitude                  0
# Longitude                 0
# Regional                  0
# Delegacia                 0
# uop,,,,,,,                0
# Año                       0
# dtype: int64

# %%
df.isnull().any().sum()
# Out:
# 0

# %%
df.dropna(inplace=True)
df.isnull().any().any()
# Out:
# False

# %%
df.duplicated().any()
# Out:
# False

# %%
df.drop_duplicates(inplace=True)
df.duplicated().any()
# Out:
# False

# %%
(df.head(5))
# Out:
#    Id_acidente Año_acidente    Dia_semana   Horario Unidad_federal     Br  \
# 0     260068.0   2020-01-01  quarta-feira  05:40:00             PA  316.0
# 1     260073.0   2020-01-01  quarta-feira  06:00:00             MG  262.0
# 2     260087.0   2020-01-01  quarta-feira  06:00:00             BA  116.0
# 3     260116.0   2020-01-01  quarta-feira  10:08:00             SP  116.0
# 4     260129.0   2020-01-01  quarta-feira  12:10:00             MG  262.0
#
#       Km              Municipio                      Causa_acidente  \
# 0     84  SAO FRANCISCO DO PARA         Falta de Atenção à Condução
# 1    804                UBERABA         Falta de Atenção à Condução
# 2    191                CANUDOS                   Condutor Dormindo
# 3     71              APARECIDA  Não guardar distância de segurança
# 4  380,9                JUATUBA                   Condutor Dormindo
#
#                Tipo_acidente  ... Ilesos Ignorados Feridos Veiculos  \
# ...

# %% [markdown]
# ### Pregunta 1: ¿Cuál es la tendencia en el número total de accidentes a lo largo de los años?
#
# En 2020, el gráfico comienza con aproximadamente 63,400 accidentes.
# Luego, en 2021, hay un pico significativo que muestra un aumento hasta alrededor de 64,200 accidentes.
# Para 2022, se observa una disminución pronunciada hasta aproximadamente 63,600 accidentes.
# El pico en 2021 puede sugerir varios factores, como cambios en las condiciones de la carretera, modificaciones en las leyes de tráfico, o incluso factores externos como el clima o eventos especiales que podrían haber contribuido al aumento de los accidentes.

# %%
accidentes_por_año = df['Año'].value_counts().sort_index().reset_index()
accidentes_por_año.columns = ['Año', 'Número de acidentes']


plt.figure(figsize=(12, 6))
plt.plot(accidentes_por_año['Año'], accidentes_por_año['Número de acidentes'], marker='o', linestyle='-')
plt.title('Tendência no número total de acidentes por ano')
plt.xlabel('Año')
plt.ylabel('Número de acidentes')
plt.grid(True)

plt.xticks(accidentes_por_año['Año'], rotation=45)


resumen_estadistico = accidentes_por_año.describe()

print(resumen_estadistico)

plt.tight_layout()
plt.show()
# Out:
#           Año  Número de acidentes
# count     3.0             3.000000
# mean   2021.0         63782.666667
# std       1.0           489.752318
# min    2020.0         63398.000000
# 25%    2020.5         63507.000000
# 50%    2021.0         63616.000000
# 75%    2021.5         63975.000000
# max    2022.0         64334.000000

# %% [markdown]
# ## Pregunta 2: ¿Existe una estacionalidad en la ocurrencia de accidentes a lo largo de los meses o las estaciones del año?
#
# Este análisis permite analizar y visualizar la distribución de accidentes a lo largo de los meses y las estaciones del año, proporcionando dos gráficos de barras y estadísticas resumidas para comprender mejor la variación de accidentes en función del tiempo
#
# Analizando el primer gráfico, parece haber una variación menor en la cantidad de accidentes de tráfico a lo largo de los meses, con los números fluctuando alrededor de una media que parece estar entre 12,000 y 15,000 accidentes por mes. No hay una tendencia clara o picos significativos que sugieran una estacionalidad fuerte en los datos mensuales.
#
# En el segundo gráfico, que muestra la distribución por estación del año, la frecuencia de accidentes también se mantiene relativamente constante entre las estaciones, aunque hay una leve disminución durante la primavera. Los números son aproximadamente:
#
# Otoño: Cerca de 50,000 accidentes
# Invierno: Ligeramente por debajo de 50,000 accidentes
# Verano: Algo más de 40,000 accidentes
# Primavera: Alrededor de 40,000 accidentes

# %%
df['Mes'] = df['Año_acidente'].dt.month
df['Estación'] = df['Mes'].apply(lambda x: 'Invierno' if (x >= 1 and x <= 2) or x == 12 else
                                            'Primavera' if x >= 3 and x <= 5 else
                                            'Verano' if x >= 6 and x <= 8 else 'Otoño')


accidentes_por_mes = df['Mes'].value_counts().sort_index().reset_index()
accidentes_por_mes.columns = ['Mes', 'Número de acidentes']


accidentes_por_estacion = df['Estación'].value_counts().reset_index()
accidentes_por_estacion.columns = ['Estación', 'Número de acidentes']


plt.figure(figsize=(12, 6))


plt.subplot(1, 2, 1)
plt.bar(accidentes_por_mes['Mes'], accidentes_por_mes['Número de acidentes'])
plt.title('Distribuição de acidentes por mês')
plt.xlabel('Mes')
plt.ylabel('')
plt.grid(True)


plt.subplot(1, 2, 2)
plt.bar(accidentes_por_estacion['Estación'], accidentes_por_estacion['Número de acidentes'])
plt.title('Distribuição de acidentes por estação do ano')
plt.xlabel('Estación del Año')
plt.ylabel('')
plt.grid(True)


resumen_mes = accidentes_por_mes.describe()
resumen_estacion = accidentes_por_estacion.describe()


print("Resumen por Mes:")
print(resumen_mes)

print("\nResumen por Estación del Año:")
print(resumen_estacion)

plt.tight_layout()
plt.show()
# Out:
# Resumen por Mes:
#              Mes  Número de acidentes
# count  12.000000            12.000000
# mean    6.500000         15945.666667
# std     3.605551          1150.506950
# min     1.000000         13964.000000
# 25%     3.750000         15161.750000
# 50%     6.500000         15931.500000
# 75%     9.250000         16596.750000
# max    12.000000         17758.000000
#
# Resumen por Estación del Año:
#        Número de acidentes
# count             4.000000
# mean          47837.000000
# std            2599.110232
# min           44106.000000
# 25%           47246.250000
# 50%           48572.500000
# 75%           49163.250000
# max           50097.000000

# %% [markdown]
# ##   3. ¿Cuáles son las condiciones meteorológicas más comunes en los accidentes y cómo afectan a la gravedad de los mismos "Mortos, Feridos_leves, Feridos_graves, Ilesos o Ignorados"?
#
# Muestran una visualización de barras apiladas que representa la frecuencia de las condiciones meteorológicas en función de la gravedad de los accidentes y proporciona estadísticas descriptivas para cada categoría de gravedad en relación con las condiciones meteorológicas. Esto ayuda a entender cómo las condiciones meteorológicas pueden influir en la gravedad de los accidentes.
#
# Cielo Claro (Céu Claro): Es la condición más comúnmente reportada en los accidentes durante los tres años, con una frecuencia que supera los 30,000 eventos anualmente.
# Lluvia (Chuva): Es la segunda condición más frecuente, con una disminución notable en el año 2022 comparado con los años anteriores.
# Sol (Sol) y Viento (Vento): Estas condiciones aparecen con menos frecuencia en los reportes de accidentes.
# Ignorado: Representa los casos en los que las condiciones meteorológicas no fueron reportadas o desconocidas. La frecuencia de esta categoría es significativamente baja comparada con las condiciones de Cielo Claro y Lluvia.
# Condiciones menos comunes: Granizo (Granizo), Niebla/Neblina (Nevoeiro/Nebulina), y Nieve (Neve) tienen las frecuencias más bajas en los datos. Esto puede ser debido a que estas condiciones son menos comunes en las áreas estudiadas o que los conductores toman precauciones adicionales bajo estas condiciones.
#
# Las condiciones menos comunes como la nieve y la neblina, a pesar de su baja frecuencia, podrían ser de interés para estudiar más a fondo debido a su potencial para causar accidentes graves. La categoría Ignorado destaca la importancia de una buena recopilación de datos para asegurar la calidad y la utilidad de los análisis de seguridad vial

# %%
warnings.filterwarnings("ignore")

columns_of_interest = ['Condicao_metereologica', 'Año', 'Mortos', 'Feridos_leves', 'Feridos_graves', 'Ilesos', 'Ignorados']
filtered_df = df[columns_of_interest]

frequency_table = filtered_df.groupby(['Condicao_metereologica', 'Año']).size().reset_index(name='Frecuencia')


frequency_table['Condicao_metereologica'] = frequency_table['Condicao_metereologica'].astype(pd.CategoricalDtype())
summary_statistics = frequency_table.groupby('Condicao_metereologica', observed=True)['Frecuencia'].describe()

plt.figure(figsize=(12, 8))
sns.set_palette("viridis")


sns.barplot(data=frequency_table, x='Condicao_metereologica', y='Frecuencia', hue='Año', estimator=sum, errorbar=None, order=frequency_table['Condicao_metereologica'].unique())


print(summary_statistics)

plt.title('Frequência das condições meteorológicas por ano')
plt.xlabel('Condições climatéricas')
plt.ylabel('')
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend(title='Año')
plt.show()

warnings.filterwarnings("default")
# Out:
#                         count          mean         std      min      25%  \
# Condicao_metereologica
# Chuva                     3.0   6843.666667  169.086763   6700.0   6750.5
# Céu Claro                 3.0  38458.666667  478.063106  37923.0  38267.0
# Garoa/Chuvisco            3.0   2214.333333  153.832160   2110.0   2126.0
# Granizo                   3.0      2.333333    0.577350      2.0      2.0
# Ignorado                  3.0    813.333333   36.226142    782.0    793.5
# Neve                      3.0      2.000000    1.000000      1.0      1.5
# Nevoeiro/Neblina          3.0    499.000000   46.184413    460.0    473.5
# Nublado                   3.0  10604.666667  310.032794  10320.0  10439.5
# Sol                       3.0   4213.000000  450.213283   3735.0   4005.0
# Vento                     3.0    131.666667   11.015141    121.0    126.0
#
#                             50%      75%      max
# Condicao_metereologica
# Chuva                    6801.0   6915.5   7030.0
# ...

# %% [markdown]
#  ##  4. ¿Qué días de la semana tienen la mayor cantidad de accidentes y cómo varía esta distribución?
# Permite comparar la frecuencia de accidentes en diferentes días de la semana a lo largo de los años entre 2020 a 2022, lo que puede ayudar a identificar patrones o tendencias en la ocurrencia de accidentes en función del día de la semana y el año.
#
# Los accidentes son menos frecuentes al comienzo de la semana, con los lunes (segunda-feira) mostrando las cifras más bajas.
# Hay un marcado aumento hacia el final de la semana, con los viernes (sexta-feira) y sábados (sábado) registrando los números más altos de accidentes.
# Esta tendencia es consistente a lo largo de los tres años, aunque las cifras absolutas pueden variar de un año a otro.
# La frecuencia de accidentes aumenta significativamente durante los fines de semana, lo que podría estar relacionado con un aumento de actividades recreativas y viajes durante estos días.
# 2022 muestra una disminución general en la frecuencia de accidentes en comparación con los años anteriores, lo que podría indicar una posible mejora en las condiciones de seguridad vial o cambios en los patrones de viaje, tal vez influenciados por eventos externos o políticas públicas.

# %%
accidents_by_day_and_year = df.groupby(['Año', 'Dia_semana']).size().unstack()

order = ['domingo', 'segunda-feira', 'terça-feira', 'quarta-feira', 'quinta-feira', 'sexta-feira', 'sábado']
accidents_by_day_and_year = accidents_by_day_and_year[order]

plt.figure(figsize=(12, 8))
sns.set_palette("husl")


accidents_by_day_and_year_transposed = accidents_by_day_and_year.T


for year in accidents_by_day_and_year_transposed.columns:
    plt.plot(accidents_by_day_and_year_transposed.index, accidents_by_day_and_year_transposed[year], marker='o', label=str(year))

plt.title('Frequência de acidentes por dia da semana')
plt.xlabel('')
plt.ylabel('')
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend(title='Año')
plt.show()

summary_statistics = accidents_by_day_and_year.describe()
print("Resumen de Accidentes por Día de la Semana:")
print(summary_statistics)
# Out:
# Resumen de Accidentes por Día de la Semana:
# Dia_semana       domingo  segunda-feira  terça-feira  quarta-feira  \
# count           3.000000       3.000000     3.000000      3.000000
# mean        10671.666667    8592.666667  7725.333333   7977.333333
# std           236.747404      88.635960    61.010928    149.001119
# min         10399.000000    8495.000000  7655.000000   7828.000000
# 25%         10595.000000    8555.000000  7706.000000   7903.000000
# 50%         10791.000000    8615.000000  7757.000000   7978.000000
# 75%         10808.000000    8641.500000  7760.500000   8052.000000
# max         10825.000000    8668.000000  7764.000000   8126.000000
#
# Dia_semana  quinta-feira   sexta-feira        sábado
# count           3.000000      3.000000      3.000000
# mean         8167.000000   9898.333333  10750.333333
# std            86.884981    208.715915     96.836632
# min          8067.000000   9750.000000  10647.000000
# ...

# %% [markdown]
# ##   5. ¿Cómo se distribuyen los tipos de carreteras en relación con los accidentes?
#
# Este gráfico de barras permite comparar la distribución de accidentes por tipo de pista en diferentes años, lo que puede ayudar
# a identificar patrones o cambios en la preferencia de tipo de pista.
#
# Las carreteras simples son las más comunes en términos de accidentes en los tres años, lo que sugiere que son las más prevalentes o que tienen un riesgo inherente de accidentes más alto.
# Las carreteras dobles tienen un número similar de accidentes a las simples, lo que podría deberse a un mayor tráfico o a factores específicos de diseño de la carretera.
# Las carreteras múltiples tienen significativamente menos accidentes, lo que podría indicar que son menos comunes o posiblemente mejor diseñadas para la seguridad.
# De año en año, hay una ligera disminución en la cantidad de accidentes en todos los tipos de carreteras, con 2022 mostrando los números más bajos en comparación con 2020 y 2021

# %%
warnings.filterwarnings("ignore")

subset_df = df[['Año', 'Tipo_pista']]

plt.figure(figsize=(12, 6))
sns.set_palette("Set3")


sns.countplot(data=subset_df, x='Tipo_pista', hue='Año')

plt.title('Distribución de Accidentes por Tipo de Pista por Año')
plt.xlabel('')
plt.ylabel('')
plt.xticks(rotation=45)
plt.legend(title='Año', loc='upper right')


plt.tight_layout()


summary_statistics = subset_df.groupby(['Año', 'Tipo_pista']).size().unstack().describe()
print("Resumo dos acidentes por tipo de pista")
print(summary_statistics)


plt.show()
warnings.filterwarnings("default")
# Out:
# Resumo dos acidentes por tipo de pista
# Tipo_pista         Dupla    Múltipla       Simples
# count           3.000000     3.00000      3.000000
# mean        26594.000000  5439.00000  31749.666667
# std           557.156172   353.83612    463.605795
# min         26083.000000  5059.00000  31346.000000
# 25%         26297.000000  5279.00000  31496.500000
# 50%         26511.000000  5499.00000  31647.000000
# 75%         26849.500000  5629.00000  31951.500000
# max         27188.000000  5759.00000  32256.000000

# %% [markdown]
# ##  6. ¿Cuál es el mes y el día con mayor cantidad de accidentes a lo largo de los años analizados?
#
# La gráfica muestra la tendencia de accidentes mes a mes durante aproximadamente dos años y medio, desde enero de 2020 hasta julio de 2022. Aquí está mi análisis como estudiante de ciencia de datos:
#
# Existe una marcada disminución inicial en el número de accidentes a principios de 2020, lo que podría corresponder a las restricciones de viaje y confinamientos debidos a la pandemia de COVID-19.
# A lo largo del tiempo, la cantidad de accidentes muestra fluctuaciones mensuales, con algunos picos notables. Estos picos podrían corresponder a meses con mayor tráfico, como las vacaciones o periodos festivos, lo cual requeriría una investigación adicional para confirmar.
# No se observa una tendencia clara ascendente o descendente a largo plazo, lo que sugiere que los factores que afectan la seguridad vial han sido relativamente constantes durante el periodo analizado.

# %%
warnings.filterwarnings("ignore")
df['DATE']=pd.to_datetime(df['Año_acidente']) # Formato datetime python 
monthly_accidents =df.groupby(df['Año_acidente'].dt.to_period('m')).size()
monthly_accidents.plot.line()
# Out:
# <Axes: xlabel='Año_acidente'>

# %%
#df['DATE']=pd.to_datetime(df['DATE'])
#monthly_accidents = df.groupby(df['DATE'].dt.to_period('M')).size()
#monthly_accidents.plot.line()

monthly_accidents1 = df.groupby(df['Año_acidente'].dt.to_period('D')).size()
monthly_accidents1.plot.line()
# Out:
# <Axes: xlabel='Año_acidente'>

# %%
type(monthly_accidents)
# Out:
# pandas.core.series.Series

# %%
max(df['DATE'])
# Out:
# Timestamp('2022-12-31 00:00:00')

# %%
min(df['DATE'])
# Out:
# Timestamp('2020-01-01 00:00:00')

# %% [markdown]
# ## 7. ¿Cómo varía el número de accidentes a lo largo de un solo día?
#
# Hay un aumento claro en la frecuencia de accidentes durante las horas de la mañana, comenzando alrededor de las 6 am y alcanzando un pico entre las 7 am y las 8 am. Este patrón podría atribuirse a la hora pico de la mañana cuando las personas viajan al trabajo o a la escuela, lo que aumenta el tráfico y, posiblemente, el potencial de accidentes.
#
# Los accidentes disminuyen después del pico matutino, pero vuelven a subir alrededor del mediodía, lo que podría corresponder a la hora de almuerzo, cuando más gente puede estar en las carreteras.
# Existe un pico aún mayor por la tarde, comenzando alrededor de las 5 pm y alcanzando su punto máximo entre las 6 pm y las 7 pm, coincidiendo con la hora punta de la tarde.
# Después de este segundo pico, la cantidad de accidentes disminuye constantemente a lo largo de la noche, con los puntos más bajos en las primeras horas de la mañana

# %%
df['Horario']=pd.to_datetime(df['Horario'])
df['HOUR'] = df['Horario'].dt.hour
hourly_accidents =df.groupby('HOUR').size()
hourly_accidents.index
hourly_accidents.values
plt.bar(hourly_accidents.index,hourly_accidents.values)
plt.title('Distribucion de accidentes por hora')
plt.xlabel('Hora')
plt.ylabel('Total de accidentes')
# Out:
# Text(0, 0.5, 'Total de accidentes')

# %%
sns.barplot(x=hourly_accidents.index, y=hourly_accidents.values)
plt.title('Distribucion de accidentes por hora')
plt.xlabel('Horario')
plt.ylabel('Total accidentes')
# Out:
# Text(0, 0.5, 'Total accidentes')

# %% [markdown]
# # Agrupación de cantidad de accidentes por Unidad Federal

# %%
df.groupby('Unidad_federal').size()
# Out:
# Unidad_federal
# AC      550
# AL     1799
# AM      234
# AP      322
# BA    10195
# CE     4477
# DF     2928
# ES     7331
# GO     9505
# MA     3364
# MG    24951
# MS     4800
# MT     6489
# PA     2626
# PB     4300
# PE     7835
# PI     3446
# PR    21818
# RJ    13456
# RN     3957
# RO     4245
# RR      514
# RS    13604
# SC    22669
# SE     1592
# SP    12694
# TO     1647
# dtype: int64

# %% [markdown]
# ## 8. ¿Cuáles son las Unidades Federales con mayores índices de accidentes?
#
# Esta gráfica muestra la cantidad de accidentes de tráfico distribuidos por Unidad Federal. Los datos están organizados de mayor a menor número de accidentes.
#
# Este informe refleja la distribución de los accidentes por Unidad Federal en Brasil, donde se puede observar que Minas Gerais (MG) tiene el mayor número de accidentes reportados con 24,951, seguido de cerca por Santa Catarina (SC) con 22,669 accidentes y Paraná (PR) con 21,818 accidentes. En contraste, los estados con menos accidentes reportados son Roraima (RR) y Amazonas (AM), con 514 y 234 accidentes respectivamente. Estas cifras podrían ser indicativas de la densidad de tráfico, las condiciones de las carreteras, o la población de cada estado, entre otros factores.

# %%
Df_1 = df.groupby('Unidad_federal').size()
Df_1_sorted = Df_1.sort_values(ascending=False)


Df_1_sorted.plot.bar()
plt.xlabel('Unidad Federal')
plt.ylabel('Cantidad de Accidentes')
plt.title('Accidentes por Unidad Federal')
plt.show()

# %% [markdown]
# ### Concñusión
#
# La tendencia anual de accidentes mostró un aumento inicial seguido de una disminución, lo que podría indicar variaciones en las medidas de seguridad vial o cambios en el comportamiento de conducción.
#
# En términos de estacionalidad, no hubo diferencias significativas en la cantidad de accidentes entre los diferentes meses y estaciones, sugiriendo que los accidentes son bastante constantes a lo largo del año y no son particularmente afectados por cambios estacionales.
#
# Las condiciones meteorológicas más comunes en los accidentes fueron cielos despejados y lluvia, con una menor frecuencia de accidentes en condiciones de niebla o nevadas. Esto podría implicar que, aunque las condiciones adversas como la lluvia son peligrosas, la mayoría de los accidentes ocurren en condiciones climáticas normales, posiblemente debido a un exceso de confianza o a una mayor cantidad de vehículos en la carretera.
#
# La frecuencia de accidentes varió a lo largo de la semana, con picos significativos en los fines de semana, lo que sugiere que el ocio o los viajes no laborales pueden jugar un rol importante en la incidencia de los accidentes.
#
# Los tipos de carreteras más comunes asociados con accidentes fueron las simples y dobles, con una cantidad menor en pistas múltiples, indicando que las carreteras más básicas, que podrían estar menos equipadas con medidas de seguridad, son más propensas a los accidentes.
#
# El análisis mensual destacó ciertas fluctuaciones en la cantidad de accidentes, con picos que podrían estar asociados con periodos vacacionales o fechas específicas en las que hay un mayor tráfico.
#
# La distribución horaria de los accidentes mostró picos durante las horas de la tarde y la noche, lo que podría estar relacionado con el aumento de tráfico durante las horas pico y la visibilidad reducida por la noche.
#
# Por último, al analizar los accidentes por Unidad Federal, se encontró que los estados con mayores índices de accidentes son Minas Gerais, Santa Catarina y Paraná, lo cual podría justificar una atención particular en términos de políticas de seguridad vial para estos estados.
#
# En general, estos análisis subrayan la complejidad y la multitud de factores que intervienen en la incidencia de accidentes de tráfico en Brasil. Los datos sugieren que hay una distribución constante de accidentes a lo largo del año y que las condiciones normales de conducción y los períodos de alto tráfico son más propensos a los accidentes que las condiciones adversas. Además, la variabilidad por estado indica que las estrategias de seguridad vial podrían necesitar ser adaptadas a las condiciones específicas de cada región. Estos hallazgos podrían ser utilizados por las autoridades para diseñar e implementar medidas de seguridad vial más efectivas y dirigidas.

# %%
unique_weapons = df['Classificacao_acidente'].unique()
print(unique_weapons)


# Voy a realizar una agrupación para que mis gráficos no sean tan grandes

vitima_mapping = {
    'Com Vítimas Feridas': '1',
    'Com Vítimas Fatais': '1',
    'Sem Vítimas': '0'

}

df['C_vitimas'] = df['Classificacao_acidente'].map(vitima_mapping) # Creo una nueva columna con áreas agrupadas

print(df[['Classificacao_acidente', 'C_vitimas']])
# Out:
# ['Com Vítimas Feridas' 'Com Vítimas Fatais' 'Sem Vítimas']
#        Classificacao_acidente C_vitimas
# 0         Com Vítimas Feridas         1
# 1         Com Vítimas Feridas         1
# 2          Com Vítimas Fatais         1
# 3         Com Vítimas Feridas         1
# 4         Com Vítimas Feridas         1
# ...                       ...       ...
# 192657    Com Vítimas Feridas         1
# 192658            Sem Vítimas         0
# 192659    Com Vítimas Feridas         1
# 192660    Com Vítimas Feridas         1
# 192661    Com Vítimas Feridas         1
#
# [191348 rows x 2 columns]

# %%
cantidad = len(df['C_vitimas'])

sns.countplot(data = df,
              x = "C_vitimas")
plt.xlabel('Sin victima/ con victima')
plt.ylabel('Numero de victimas')
plt.title('Target variable distribution')
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(int(y_text)/cantidad,2) * 100)}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')

# %% [markdown]
# ## Variable Target

# %% [markdown]
# Se utilizará esta variable como variable target ya que en ella se observa que en cada accidentes se producen el 82% de victimas y sólo el 18% de los casos no poseen victimas.

# %%
# Genero un dataframe que voy a ir completando con cada IV
IV_df = pd.DataFrame(columns=['Variable', 'IV'])
IV_df.head()
# Out:
# Empty DataFrame
# Columns: [Variable, IV]
# Index: []

# %%
# Ejemplo de conversión de tipos de datos
df['C_vitimas'] = df['C_vitimas'].astype(int)

# %% [markdown]
# ## variable Fase_dia

# %%
df['C_vitimas'] = pd.to_numeric(df['C_vitimas'], errors='coerce')

# Tu código original para crear tabla_IV, después de asegurarte de que 'C_vitimas' es numérica
tabla_IV = df.groupby('Fase_dia').agg(      
    Cant = ('C_vitimas', 'count'),
    Cant_vitimas = ('C_vitimas', 'sum'),    
    Tasa_vitimas = ('C_vitimas', 'mean')
).reset_index()
tabla_IV['Tasa_SV'] = 1 - tabla_IV['Tasa_vitimas']
tabla_IV['Cant_SV'] = tabla_IV['Cant'] - tabla_IV['Cant_vitimas']
tabla_IV['LN'] = np.log(tabla_IV['Tasa_vitimas'] / tabla_IV['Tasa_SV'])
tabla_IV['Pct_Vitimas'] = tabla_IV['Cant_vitimas'] / sum(tabla_IV['Cant_vitimas'])
tabla_IV['Pct_SV'] = tabla_IV['Cant_SV'] / sum(tabla_IV['Cant_SV'])
tabla_IV['Resta'] = tabla_IV['Pct_Vitimas'] - tabla_IV['Pct_SV']
tabla_IV['IV'] = tabla_IV['Resta'] * tabla_IV['LN']

# %%
nuevo_dato = {'Variable': 'Fase_dia', 'IV': sum(tabla_IV['IV'])}

IV_df = pd.concat([IV_df, pd.DataFrame([nuevo_dato])], ignore_index=True)

IV_df.head()
# Out:
#    Variable        IV
# 0  Fase_dia  0.032964

# %% [markdown]
# ## variable Sentido_via

# %%
tabla_IV = df.groupby('Sentido_via').agg(      
    Cant = ('C_vitimas', 'count'),
    Cant_vitimas = ('C_vitimas', 'sum'),    
    Tasa_vitimas = ('C_vitimas', 'mean')
).reset_index()
tabla_IV['Tasa_SV'] = 1 - tabla_IV['Tasa_vitimas']
tabla_IV['Cant_SV'] = tabla_IV['Cant'] - tabla_IV['Cant_vitimas']
tabla_IV['LN'] = np.log(tabla_IV['Tasa_vitimas'] / tabla_IV['Tasa_SV'])
tabla_IV['Pct_Vitimas'] = tabla_IV['Cant_vitimas'] / sum(tabla_IV['Cant_vitimas'])
tabla_IV['Pct_SV'] = tabla_IV['Cant_SV'] / sum(tabla_IV['Cant_SV'])
tabla_IV['Resta'] = tabla_IV['Pct_Vitimas'] - tabla_IV['Pct_SV']
tabla_IV['IV'] = tabla_IV['Resta'] * tabla_IV['LN']
tabla_IV
# Out:
#    Sentido_via    Cant  Cant_vitimas  Tasa_vitimas   Tasa_SV  Cant_SV  \
# 0    Crescente  101863         83870      0.823361  0.176639    17993
# 1  Decrescente   89485         73124      0.817165  0.182835    16361
#
#          LN  Pct_Vitimas    Pct_SV     Resta        IV
# 0  1.539285     0.534224  0.523753  0.010472  0.016119
# 1  1.497256     0.465776  0.476247 -0.010472 -0.015679

# %%
nuevo_dato = {'Variable': 'Sentido_via', 'IV': sum(tabla_IV['IV'])}

IV_df = pd.concat([IV_df, pd.DataFrame([nuevo_dato])], ignore_index=True)

IV_df.head()
# Out:
#       Variable        IV
# 0     Fase_dia  0.032964
# 1  Sentido_via  0.000440

# %% [markdown]
# ## variable Condicao_metereologica

# %%
tabla_IV = df.groupby('Condicao_metereologica').agg(      
    Cant = ('C_vitimas', 'count'),
    Cant_vitimas = ('C_vitimas', 'sum'),    
    Tasa_vitimas = ('C_vitimas', 'mean')
).reset_index()
tabla_IV['Tasa_SV'] = 1 - tabla_IV['Tasa_vitimas']
tabla_IV['Cant_SV'] = tabla_IV['Cant'] - tabla_IV['Cant_vitimas']
tabla_IV['LN'] = np.log(tabla_IV['Tasa_vitimas'] / tabla_IV['Tasa_SV'])
tabla_IV['Pct_Vitimas'] = tabla_IV['Cant_vitimas'] / sum(tabla_IV['Cant_vitimas'])
tabla_IV['Pct_SV'] = tabla_IV['Cant_SV'] / sum(tabla_IV['Cant_SV'])
tabla_IV['Resta'] = tabla_IV['Pct_Vitimas'] - tabla_IV['Pct_SV']
tabla_IV['IV'] = tabla_IV['Resta'] * tabla_IV['LN']
tabla_IV
# Out:
#   Condicao_metereologica    Cant  Cant_vitimas  Tasa_vitimas   Tasa_SV  \
# 0                  Chuva   20531         16629      0.809946  0.190054
# 1              Céu Claro  115376         94711      0.820890  0.179110
# 2         Garoa/Chuvisco    6643          5262      0.792112  0.207888
# 3                Granizo       7             5      0.714286  0.285714
# 4               Ignorado    2440          1985      0.813525  0.186475
# 5                   Neve       6             5      0.833333  0.166667
# 6       Nevoeiro/Neblina    1497          1148      0.766867  0.233133
# 7                Nublado   31814         26144      0.821777  0.178223
# 8                    Sol   12639         10801      0.854577  0.145423
# 9                  Vento     395           304      0.769620  0.230380
#
#    Cant_SV        LN  Pct_Vitimas    Pct_SV     Resta        IV
# 0     3902  1.449659     0.105921  0.113582 -0.007661 -0.011106
# ...

# %%
nuevo_dato = {'Variable': 'Condicao_metereologica', 'IV': sum(tabla_IV['IV'])}

IV_df = pd.concat([IV_df, pd.DataFrame([nuevo_dato])], ignore_index=True)

IV_df.head()
# Out:
#                  Variable        IV
# 0                Fase_dia  0.032964
# 1             Sentido_via  0.000440
# 2  Condicao_metereologica  0.006818

# %% [markdown]
# ## variable Tipo_pista

# %%
tabla_IV = df.groupby('Tipo_pista').agg(      
    Cant = ('C_vitimas', 'count'),
    Cant_vitimas = ('C_vitimas', 'sum'),    
    Tasa_vitimas = ('C_vitimas', 'mean')
).reset_index()
tabla_IV['Tasa_SV'] = 1 - tabla_IV['Tasa_vitimas']
tabla_IV['Cant_SV'] = tabla_IV['Cant'] - tabla_IV['Cant_vitimas']
tabla_IV['LN'] = np.log(tabla_IV['Tasa_vitimas'] / tabla_IV['Tasa_SV'])
tabla_IV['Pct_Vitimas'] = tabla_IV['Cant_vitimas'] / sum(tabla_IV['Cant_vitimas'])
tabla_IV['Pct_SV'] = tabla_IV['Cant_SV'] / sum(tabla_IV['Cant_SV'])
tabla_IV['Resta'] = tabla_IV['Pct_Vitimas'] - tabla_IV['Pct_SV']
tabla_IV['IV'] = tabla_IV['Resta'] * tabla_IV['LN']
tabla_IV
# Out:
#   Tipo_pista   Cant  Cant_vitimas  Tasa_vitimas   Tasa_SV  Cant_SV        LN  \
# 0      Dupla  79782         64361      0.806711  0.193289    15421  1.428778
# 1   Múltipla  16317         13448      0.824171  0.175829     2869  1.544867
# 2    Simples  95249         79185      0.831347  0.168653    16064  1.595206
#
#    Pct_Vitimas    Pct_SV     Resta        IV
# 0     0.409958  0.448885 -0.038927 -0.055618
# 1     0.085659  0.083513  0.002146  0.003316
# 2     0.504382  0.467602  0.036780  0.058672

# %%
nuevo_dato = {'Variable': 'Tipo_pista', 'IV': sum(tabla_IV['IV'])}

IV_df = pd.concat([IV_df, pd.DataFrame([nuevo_dato])], ignore_index=True)

IV_df.head()
# Out:
#                  Variable        IV
# 0                Fase_dia  0.032964
# 1             Sentido_via  0.000440
# 2  Condicao_metereologica  0.006818
# 3              Tipo_pista  0.006370

# %% [markdown]
# ## variable Tracado_via

# %%
tabla_IV = df.groupby('Tracado_via').agg(      
    Cant = ('C_vitimas', 'count'),
    Cant_vitimas = ('C_vitimas', 'sum'),    
    Tasa_vitimas = ('C_vitimas', 'mean')
).reset_index()
tabla_IV['Tasa_SV'] = 1 - tabla_IV['Tasa_vitimas']
tabla_IV['Cant_SV'] = tabla_IV['Cant'] - tabla_IV['Cant_vitimas']
tabla_IV['LN'] = np.log(tabla_IV['Tasa_vitimas'] / tabla_IV['Tasa_SV'])
tabla_IV['Pct_Vitimas'] = tabla_IV['Cant_vitimas'] / sum(tabla_IV['Cant_vitimas'])
tabla_IV['Pct_SV'] = tabla_IV['Cant_SV'] / sum(tabla_IV['Cant_SV'])
tabla_IV['Resta'] = tabla_IV['Pct_Vitimas'] - tabla_IV['Pct_SV']
tabla_IV['IV'] = tabla_IV['Resta'] * tabla_IV['LN']
tabla_IV
# Out:
#              Tracado_via    Cant  Cant_vitimas  Tasa_vitimas   Tasa_SV  \
# 0                  Curva   28772         23707      0.823961  0.176039
# 1      Desvio Temporário    5381          4408      0.819179  0.180821
# 2     Interseção de vias    8088          6811      0.842112  0.157888
# 3          Não Informado   25068         20707      0.826033  0.173967
# 4                  Ponte    1022           795      0.777886  0.222114
# 5                   Reta  115557         94599      0.818635  0.181365
# 6  Retorno Regulamentado    2272          1822      0.801937  0.198063
# 7              Rotatória    3594          2855      0.794380  0.205620
# 8                  Túnel     256           198      0.773438  0.226562
# 9                Viaduto    1338          1092      0.816143  0.183857
#
#    Cant_SV        LN  Pct_Vitimas    Pct_SV     Resta        IV
# 0     5065  1.543416     0.151006  0.147436  0.003570  0.005510
# ...

# %%
nuevo_dato = {'Variable': 'Tracado_via', 'IV': sum(tabla_IV['IV'])}

IV_df = pd.concat([IV_df, pd.DataFrame([nuevo_dato])], ignore_index=True)

IV_df.head()
# Out:
#                  Variable        IV
# 0                Fase_dia  0.032964
# 1             Sentido_via  0.000440
# 2  Condicao_metereologica  0.006818
# 3              Tipo_pista  0.006370
# 4             Tracado_via  0.002611

# %% [markdown]
# ## variable Dia_semana

# %%
tabla_IV = df.groupby('Dia_semana').agg(      
    Cant = ('C_vitimas', 'count'),
    Cant_vitimas = ('C_vitimas', 'sum'),    
    Tasa_vitimas = ('C_vitimas', 'mean')
).reset_index()
tabla_IV['Tasa_SV'] = 1 - tabla_IV['Tasa_vitimas']
tabla_IV['Cant_SV'] = tabla_IV['Cant'] - tabla_IV['Cant_vitimas']
tabla_IV['LN'] = np.log(tabla_IV['Tasa_vitimas'] / tabla_IV['Tasa_SV'])
tabla_IV['Pct_Vitimas'] = tabla_IV['Cant_vitimas'] / sum(tabla_IV['Cant_vitimas'])
tabla_IV['Pct_SV'] = tabla_IV['Cant_SV'] / sum(tabla_IV['Cant_SV'])
tabla_IV['Resta'] = tabla_IV['Pct_Vitimas'] - tabla_IV['Pct_SV']
tabla_IV['IV'] = tabla_IV['Resta'] * tabla_IV['LN']
tabla_IV
# Out:
#       Dia_semana   Cant  Cant_vitimas  Tasa_vitimas   Tasa_SV  Cant_SV  \
# 0        domingo  32015         25311      0.790598  0.209402     6704
# 1   quarta-feira  23932         19953      0.833737  0.166263     3979
# 2   quinta-feira  24501         20266      0.827150  0.172850     4235
# 3  segunda-feira  25778         21598      0.837846  0.162154     4180
# 4    sexta-feira  29695         24611      0.828793  0.171207     5084
# 5         sábado  32251         25883      0.802549  0.197451     6368
# 6    terça-feira  23176         19372      0.835865  0.164135     3804
#
#          LN  Pct_Vitimas    Pct_SV     Resta        IV
# 0  1.328535     0.161223  0.195145 -0.033922 -0.045066
# 1  1.612349     0.127094  0.115823  0.011271  0.018172
# 2  1.565561     0.129088  0.123275  0.005812  0.009100
# 3  1.642289     0.137572  0.121674  0.015898  0.026109
# 4  1.577095     0.156764  0.147989  0.008775  0.013840
# 5  1.402301     0.164866  0.185364 -0.020498 -0.028744
# ...

# %%
nuevo_dato = {'Variable': 'Dia_semana', 'IV': sum(tabla_IV['IV'])}

IV_df = pd.concat([IV_df, pd.DataFrame([nuevo_dato])], ignore_index=True)

IV_df.head(6)
# Out:
#                  Variable        IV
# 0                Fase_dia  0.032964
# 1             Sentido_via  0.000440
# 2  Condicao_metereologica  0.006818
# 3              Tipo_pista  0.006370
# 4             Tracado_via  0.002611
# 5              Dia_semana  0.014023

# %%
# Grafico el information value de cada variable
IV_df = IV_df.sort_values(by = 'IV', ascending = False)
plt.figure(figsize=(10, 6))  # Tamaño de la figura
plt.barh(IV_df['Variable'], 
         IV_df['IV'],
         color = '#A989D6')
plt.xlabel('Information Value')
plt.gca().invert_yaxis()  # Invertir el eje Y para mostrar la característica más relevante en la parte superior
plt.show()

# %% [markdown]
# Conclusión: utilizaré para mis modelos las features "Fase_dia" y "Dia_semana" porque demostraron tener una fuerte relación predictiva con la variable objetivo.

# %% [markdown]
# Convertí las variables categóricas 'Fase_dia' y 'Sentido_via' en numéricas mediante codificación, para que pudieran ser utilizadas por mi modelo. Además, creé la matriz de predictores X y el vector objetivo y para los siguientes pasos.

# %%
# Supongamos que 'Fase_dia' es una columna categórica que contiene 'Pleno dia', 'Plena Noite', 'Anoitecer' y 'Amanhecer'
df['F_dia'] = df['Fase_dia'].map({'Pleno dia': 1, 'Plena Noite': 2, 'Anoitecer': 3, 'Amanhecer': 0})

# Corregir el nombre de la columna 'D'

df['D_semana'] = df['Dia_semana'].map({'domingo': 0, 'quarta-feira': 1, 'quinta-feira':2, 'segunda-feira':3, 'sexta-feira':4,'sábado':5,'terça-feira': 6})

# Imprimir el DataFrame con las nuevas columnas
print(df[['F_dia', 'D_semana']])
# Out:
#         F_dia  D_semana
# 0           1         1
# 1           1         1
# 2           1         1
# 3           1         1
# 4           1         1
# ...       ...       ...
# 192657      2         0
# 192658      2         6
# 192659      2         6
# 192660      1         0
# 192661      3         2
#
# [191348 rows x 2 columns]

# %% [markdown]
# ## Arbol de desición

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
import matplotlib.pyplot as plt

# Aplicación de tus transformaciones
df['F_dia'] = df['Fase_dia'].map({'Pleno dia': 1, 'Plena Noite': 2, 'Anoitecer': 3, 'Amanhecer': 0})
df['D_semana'] = df['Dia_semana'].map({'domingo': 0, 'quarta-feira': 1, 'quinta-feira': 2, 'segunda-feira': 3, 'sexta-feira': 4, 'sábado': 5, 'terça-feira': 6})

# Defino la matriz predictores y el vector C_vitimas
X = df[['F_dia', 'D_semana']]  # Matriz de predictores
y = df['C_vitimas']  # Vector objetivo

# División de los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=43)

# Creación y configuración del modelo de árbol de decisión
clf = DecisionTreeClassifier(random_state=1234, criterion='gini', splitter='best', max_depth=4, min_samples_leaf=20)

# Entrenamiento del modelo
model = clf.fit(X_train, y_train)

# Impresión del árbol de decisión en formato de texto
print("Árbol de Decisión:")
text_representation = export_text(model, feature_names=['F_dia', 'D_semana'])
print(text_representation)

# Gráfico del árbol de decisión
plt.figure(figsize=(20, 15))
plot_tree(model, 
          filled=True, 
          rounded=True, 
          class_names=['Clase1', 'Clase2'],  # Ajusta 'Clase1', 'Clase2' según las categorías reales de tu 'Target'
          feature_names=['F_dia', 'D_semana'], 
          impurity=False,
          proportion=True,
          node_ids=True,
          fontsize=10)
plt.show()
# Out:
# Árbol de Decisión:
# |--- F_dia <= 1.50
# |   |--- F_dia <= 0.50
# |   |   |--- D_semana <= 0.50
# |   |   |   |--- class: 1
# |   |   |--- D_semana >  0.50
# |   |   |   |--- D_semana <= 5.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- D_semana >  5.50
# |   |   |   |   |--- class: 1
# |   |--- F_dia >  0.50
# |   |   |--- D_semana <= 0.50
# |   |   |   |--- class: 1
# |   |   |--- D_semana >  0.50
# |   |   |   |--- D_semana <= 4.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- D_semana >  4.50
# |   |   |   |   |--- class: 1
# |--- F_dia >  1.50
# |   |--- F_dia <= 2.50
# |   |   |--- D_semana <= 0.50
# |   |   |   |--- class: 1
# |   |   |--- D_semana >  0.50
# |   |   |   |--- D_semana <= 4.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- D_semana >  4.50
# |   |   |   |   |--- class: 1
# |   |--- F_dia >  2.50
# |   |   |--- D_semana <= 0.50
# |   |   |   |--- class: 1
# |   |   |--- D_semana >  0.50
# |   |   |   |--- D_semana <= 3.50
# ...

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Generar predicciones en el conjunto de entrenamiento
y_train_pred = model.predict(X_train)

# Generar predicciones en el conjunto de prueba
y_test_pred = model.predict(X_test)

# Calcular las métricas de evaluación para el conjunto de entrenamiento
print("Evaluación en el conjunto de entrenamiento:")
print("Accuracy:", accuracy_score(y_train, y_train_pred))
print("Classification Report:")
print(classification_report(y_train, y_train_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_train, y_train_pred))

# Calcular las métricas de evaluación para el conjunto de prueba
print("\nEvaluación en el conjunto de prueba:")
print("Accuracy:", accuracy_score(y_test, y_test_pred))
print("Classification Report:")
print(classification_report(y_test, y_test_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_test_pred))
# Out:
# Evaluación en el conjunto de entrenamiento:
# Accuracy: 0.8205505326892782
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     24036
#            1       0.82      1.00      0.90    109907
#
#     accuracy                           0.82    133943
#    macro avg       0.41      0.50      0.45    133943
# weighted avg       0.67      0.82      0.74    133943
#
# Confusion Matrix:
# [[     0  24036]
#  [     0 109907]]
#
# Evaluación en el conjunto de prueba:
# Accuracy: 0.8202595592718405
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     10318
#            1       0.82      1.00      0.90     47087
#
#     accuracy                           0.82     57405
#    macro avg       0.41      0.50      0.45     57405
# weighted avg       0.67      0.82      0.74     57405
#
# Confusion Matrix:
# [[    0 10318]
#  [    0 47087]]

# %%
# Imprimir las matrices de confusión para ambos conjuntos
print("Matriz de confusión para el conjunto de entrenamiento:")
train_confusion_matrix = confusion_matrix(y_train, y_train_pred)
print(train_confusion_matrix)

print("\nMatriz de confusión para el conjunto de prueba:")
test_confusion_matrix = confusion_matrix(y_test, y_test_pred)
print(test_confusion_matrix)

# Graficar las matrices de confusión utilizando Seaborn
fig, ax = plt.subplots(1, 2, figsize=(16, 6))

# Conjunto de entrenamiento
sns.heatmap(train_confusion_matrix, annot=True, ax=ax[0], cmap='Blues', fmt='g')
ax[0].set_title('Conjunto de Entrenamiento')
ax[0].set_xlabel('Predicciones')
ax[0].set_ylabel('Verdaderos')

# Conjunto de prueba
sns.heatmap(test_confusion_matrix, annot=True, ax=ax[1], cmap='Blues', fmt='g')
ax[1].set_title('Conjunto de Prueba')
ax[1].set_xlabel('Predicciones')
ax[1].set_ylabel('Verdaderos')

plt.show()
# Out:
# Matriz de confusión para el conjunto de entrenamiento:
# [[     0  24036]
#  [     0 109907]]
#
# Matriz de confusión para el conjunto de prueba:
# [[    0 10318]
#  [    0 47087]]

# %% [markdown]
# En el entrenamiento, el modelo tuvo una precisión del 82% y en la prueba, anduvo cerca del 79%. Aunque parece que está acertando bastante, está claro que tiende a pasar por alto algunos casos positivos, razón por el cuál el modelo debe ser mejorado.

# %% [markdown]
# ## Modelo 2: Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# Aplicación de tus transformaciones
df['F_dia'] = df['Fase_dia'].map({'Pleno dia': 1, 'Plena Noite': 2, 'Anoitecer': 3, 'Amanhecer': 0})
df['D_semana'] = df['Dia_semana'].map({'domingo': 0, 'quarta-feira': 1, 'quinta-feira': 2, 'segunda-feira': 3, 'sexta-feira': 4, 'sábado': 5, 'terça-feira': 6})

# Defino la matriz predictores y el vector C_vitimas
X = df[['F_dia', 'D_semana']]
y = df['C_vitimas']

# División de los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=43)

# Creación y configuración del modelo de Random Forest
clf = RandomForestClassifier(random_state=1234, n_estimators=100, criterion='gini', max_depth=4, min_samples_leaf=20)

# Entrenamiento del modelo
model = clf.fit(X_train, y_train)


print("Importancia de las características:")
for feature, importance in zip(['F_dia', 'D_semana'], model.feature_importances_):
    print(f"{feature}: {importance:.2f}")

# Evaluar el modelo utilizando, por ejemplo, el método de puntuación incorporado, que devuelve la precisión.
print("Precisión del conjunto de entrenamiento:", model.score(X_train, y_train))
print("Precisión del conjunto de prueba:", model.score(X_test, y_test))
# Out:
# Importancia de las características:
# F_dia: 0.73
# D_semana: 0.27
# Precisión del conjunto de entrenamiento: 0.8205505326892782
# Precisión del conjunto de prueba: 0.8202595592718405

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
from sklearn.preprocessing import label_binarize
import numpy as np

# Asumiendo que df es tu DataFrame y que las columnas 'Fase_dia', 'Dia_semana' y 'C_vitimas' ya existen

# Aplicación de tus transformaciones
df['F_dia'] = df['Fase_dia'].map({'Pleno dia': 1, 'Plena Noite': 2, 'Anoitecer': 3, 'Amanhecer': 0})
df['D_semana'] = df['Dia_semana'].map({'domingo': 0, 'quarta-feira': 1, 'quinta-feira': 2, 'segunda-feira': 3, 'sexta-feira': 4, 'sábado': 5, 'terça-feira': 6})

# Defino la matriz predictores y el vector C_vitimas
X = df[['F_dia', 'D_semana']]  # Matriz de predictores
y = df['C_vitimas']  # Vector objetivo

# División de los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=43)

# Creación del clasificador Random Forest
clf = RandomForestClassifier(random_state=1234, n_estimators=100, criterion='gini', max_depth=4, min_samples_leaf=20)

# Entrenamiento del modelo con los datos de entrenamiento
clf.fit(X_train, y_train)

# Generar las predicciones en los conjuntos de entrenamiento y prueba
y_train_pred = clf.predict(X_train)
y_test_pred = clf.predict(X_test)

# Calcular la precisión del modelo
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)
print(f'Precisión del conjunto de entrenamiento: {train_accuracy}')
print(f'Precisión del conjunto de prueba: {test_accuracy}')

# Calcular la precisión por clase, recall y F1-score por clase
print("Reporte de clasificación para el conjunto de entrenamiento:")
print(classification_report(y_train, y_train_pred))
print("Reporte de clasificación para el conjunto de prueba:")
print(classification_report(y_test, y_test_pred))

# Calcular el AUC-ROC
# AUC-ROC requiere etiquetas binarizadas para el cálculo multiclase
y_test_binarized = label_binarize(y_test, classes=np.unique(y))
y_test_pred_proba = clf.predict_proba(X_test)
# AUC-ROC sólo tiene sentido para problemas de clasificación binaria o multiclase con probabilidades
if y_test_binarized.shape[1] == 1:
    # Es un problema de clasificación binaria
    test_auc_roc = roc_auc_score(y_test, y_test_pred_proba[:,1])
else:
    # Es un problema de clasificación multiclase
    test_auc_roc = roc_auc_score(y_test_binarized, y_test_pred_proba, multi_class='ovr')

print(f'AUC-ROC para el conjunto de prueba: {test_auc_roc}')
# Out:
# Precisión del conjunto de entrenamiento: 0.8205505326892782
# Precisión del conjunto de prueba: 0.8202595592718405
# Reporte de clasificación para el conjunto de entrenamiento:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     24036
#            1       0.82      1.00      0.90    109907
#
#     accuracy                           0.82    133943
#    macro avg       0.41      0.50      0.45    133943
# weighted avg       0.67      0.82      0.74    133943
#
# Reporte de clasificación para el conjunto de prueba:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     10318
#            1       0.82      1.00      0.90     47087
#
#     accuracy                           0.82     57405
#    macro avg       0.41      0.50      0.45     57405
# weighted avg       0.67      0.82      0.74     57405
#
# AUC-ROC para el conjunto de prueba: 0.5581128981930578

# %%
from sklearn.metrics import roc_curve

y_train_proba = [0.82] * len(y_train)  
y_test_proba = [0.82] * len(y_test)

# Calcular la tasa de verdaderos positivos (recall) y la tasa de falsos positivos para ambos conjuntos
train_fpr, train_tpr, _ = roc_curve(y_train, y_train_proba, pos_label=1)
test_fpr, test_tpr, _ = roc_curve(y_test, y_test_proba, pos_label=1)

# Calcular el área bajo la curva ROC para ambos conjuntos
train_auc = roc_auc_score(y_train, y_train_proba)
test_auc = roc_auc_score(y_test, y_test_proba)

# Graficar la curva ROC para ambos conjuntos
plt.figure(figsize=(8, 6))
plt.plot(train_fpr, train_tpr, label=f'ROC curva de entrenamiento (AUC = {train_auc:.2f})', color='blue')
plt.plot(test_fpr, test_tpr, label=f'ROC curva de prueba (AUC = {test_auc:.2f})', color='red')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos (Recall)')
plt.title('Curva ROC')
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusión:
# El modelo de Random Forest muestra una alta precisión del 82%, pero falla en detectar la clase negativa, indicando un sesgo hacia la clase positiva. La curva ROC, con un AUC de 0.56, sugiere que el modelo apenas supera el rendimiento aleatorio. Para mejorar, es necesario abordar el desequilibrio de las clases.

# %% [markdown]
# ## Optimización

# %%
# Aplicación de tus transformaciones
df['F_dia'] = df['Fase_dia'].map({'Pleno dia': 1, 'Plena Noite': 2, 'Anoitecer': 3, 'Amanhecer': 0})
df['D_semana'] = df['Dia_semana'].map({'domingo': 0, 'quarta-feira': 1, 'quinta-feira': 2, 'segunda-feira': 3, 'sexta-feira': 4, 'sábado': 5, 'terça-feira': 6})

# Defino la matriz predictores y el vector C_vitimas
X = df[['F_dia', 'D_semana']]
y = df['C_vitimas']

# Separo los datos en conjuntos de entrenamiento y prueba

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Defino el modelo base

rf_model = RandomForestClassifier()

# Defino la cuadrícula de hiperparámetros a buscar

param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
# Inicio la búsqueda en cuadrícula

grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5, scoring='accuracy')

# %%
# Entreno el modelo utilizando la búsqueda en cuadrícula

grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [None, 10, 20],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]},
#              scoring='accuracy')

# %%
# Obtengo los mejores hiperparámetros encontrados

best_params = grid_search.best_params_
print("Mejores hiperparámetros:", best_params)

# Obtengo el mejor modelo

best_model = grid_search.best_estimator_

# Genero las predicciones

predictions = best_model.predict(X_test)
# Out:
# Mejores hiperparámetros: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}

# %%
# Genero un nuevo modelo utilizando los mejores hiperparámetros
best_rf_model = RandomForestClassifier(**best_params)

# Entreno el modelo con todos los datos de entrenamiento
best_rf_model.fit(X, y)

# Evelúo el rendimiento del modelo utilizando el conjunto de prueba
accuracy = best_rf_model.score(X_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8225415904537933

# %% [markdown]
# ### Conclusión:
#
# Luego de utilizar el modelo con hiperparámetros se puede observar que el modelo con mayor accuracy fue el 2 - Random Forest con Accuracy: 0.8225415904537933

# %% [markdown]
# El modelo Random Forest mejorado alcanzó una precisión del 82.25% en el conjunto de prueba, lo que representa un avance respecto a la precisión inicial del 82%. Este aumento, aunque modesto, sugiere que el proceso de ajuste de hiperparámetros ha tenido un impacto positivo en la capacidad del modelo para hacer predicciones correctas. No obstante, es crucial recordar que la precisión por sí sola no siempre es el mejor indicador de rendimiento, especialmente en conjuntos de datos con desequilibrio de clases como parece ser el caso aquí.
#
# Anteriormente, el modelo mostraba una tendencia a predecir principalmente la clase mayoritaria, ignorando la clase minoritaria. El AUC-ROC de 0.56 para el conjunto de prueba antes de la optimización indicaba que el modelo no estaba discriminando efectivamente entre las clases positiva y negativa. Si el ajuste de hiperparámetros no abordó específicamente el desequilibrio de clases, es posible que el modelo siga sin ser capaz de identificar adecuadamente la clase minoritaria.
#
# Para llegar a una conclusión final sólida y garantizar que el modelo es verdaderamente efectivo, sería importante verificar si la mejora en la precisión se refleja también en una mejor identificación de la clase minoritaria. Esto podría hacerse examinando métricas como el recall, la precisión y el F1-score para ambas clases, así como el AUC-ROC actualizado. Si estas métricas muestran una mejora, podríamos estar más seguros de que el modelo no solo es preciso sino también equilibrado y justo.
#
# En resumen, aunque la optimización de hiperparámetros ha resultado en un modelo más preciso, debemos profundizar en el análisis de otras métricas de rendimiento para asegurar que el modelo es robusto y funciona bien en todas las clases del conjunto de datos.
